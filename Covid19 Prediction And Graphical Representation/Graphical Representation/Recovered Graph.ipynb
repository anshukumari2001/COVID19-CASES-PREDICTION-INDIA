# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df= pd.read_csv("Recovered.csv")

# %%
df
# Out:
#     Month  Recovered Cases
# 0  30-Jan                0
# 1  15-Feb                1
# 2   1-Mar                3
# 3  15-Mar               16
# 4   1-Apr              188
# 5  15-Apr             1653
# 6   1-May            10983
# 7  15-May            32479
# 8  25-May            63718

# %%
x= df["Month"]
y= df["Recovered Cases"]

# %%
plt.figure(figsize=(16,9))
axes = plt.gca()
axes.set_ylim([0,160000])
plt.plot(x,y,color="blue")
plt.title("India's Rcovered Cases", fontsize=25)
plt.xlabel("Month", fontsize=20)
plt.ylabel("Recovered Cases", fontsize=20)
plt.show()

# %%
from matplotlib import style
style.use("ggplot")

width=0.2
plt.figure(figsize=(16,9))
axes = plt.gca()
axes.set_ylim([0,160000])
plt.bar(x,y,color="g",width=0.6,label="Recovered Cases")


plt.grid(color="k",linestyle="-",linewidth="2")
plt.title("India's Recovered Cases",fontsize=25)
plt.xlabel("Month",fontsize=20)
plt.ylabel("Recovered Cases",fontsize=20)
plt.legend(loc=2,fontsize=20)

plt.show()

# %%
plt.figure(figsize=(16,9))
axes = plt.gca()
axes.set_ylim([0,160000])
plt.scatter(x,y,color="r",marker=".",s=45,alpha=0.8,linewidths=5,edgecolor="r")
plt.title("India's Confirmed Cases",fontsize=25)
plt.xlabel("Month",fontsize=20)
plt.ylabel("Confirmed Cases",fontsize=20)
# Out:
# Text(0, 0.5, 'Confirmed Cases')

# %%
textprops={"fontsize":18}

plt.pie(y,labels=x,radius=4,textprops=textprops,autopct="%0.2f%%" )
plt.show()
