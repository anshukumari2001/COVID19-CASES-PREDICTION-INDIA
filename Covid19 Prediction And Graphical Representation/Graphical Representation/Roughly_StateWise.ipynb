# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Stateconfirmed.csv")
data
# Out:
#                 Unnamed: 0  14-Mar-20  15-Mar-20  16-Mar-20  17-Mar-20  \
# 0                    India         81        108        123        134
# 1      Andaman And Nicobar          0          0          0          0
# 2           Andhra Pradesh          1          1          1          1
# 3        Arunachal Pradesh          0          0          0          0
# 4                    Assam          0          0          0          0
# 5                    Bihar          0          0          0          0
# 6               Chandigarh          0          0          0          0
# 7              Chattisgarh          0          0          0          0
# 8            Daman And Deu          0          0          0          0
# 9                    Delhi          7          7          7          8
# 10  Dadra And Nagar Haveli          0          0          0          0
# 11                     Goa          0          0          0          0
# ...

# %%
real_x=data.iloc[[2,24,9,12,21,28,30,33,35,37],[0]]
real_y=data.iloc[[2,24,9,12,21,28,30,33,35,37],[57,58,59,60,61,62,63,64,65,66]]

# %%
real_x
# Out:
#         Unnamed: 0
# 2   Andhra Pradesh
# 24  Madhya Pradesh
# 9            Delhi
# 12          Gujrat
# 21     Maharashtra
# 28          Punjab
# 30       Rajasthan
# 33       Tamilnadu
# 35   Uttar Pradesh
# 37     West Bengal

# %%
real_y
# Out:
#     09-May-20  10-May-20  11-May-20  12-May-20  13-May-20  14-May-20  \
# 2        1930       1980       2018       2089       2137       2205
# 24       3457       3614       3785       3986       4173       4426
# 9        6542       6923       7233       7639       7998       8470
# 12       7797       8195       8542       8904       9268       9592
# 21      20228      22171      23401      24427      25922      27524
# 28       1762       1823       1877       1914       1924       1935
# 30       3708       3814       3988       4126       4328       4534
# 33       6535       7204       8002       8718       9227       9674
# 35       3373       3467       3573       3664       3758       3902
# 37       1786       1939       2063       2173       2290       2377
#
#     15-May-20  16-May-20  17-May-20  18-May-20
# 2        2289       2337       2362       2414
# 24       4595       4790       4977       5236
# 9        8895       9333       9755      10054
# ...

# %%
x=real_x["Unnamed: 0"]
y=real_y[[
"09-May-20",
"10-May-20",
"11-May-20",
"12-May-20",
"13-May-20",
"14-May-20",
"15-May-20",
"16-May-20",
"17-May-20",
"18-May-20"]]

# %%
#plt.plot(x,y)
from matplotlib import style
style.use("ggplot")
plt.figure(figsize=(16,9))
plt.plot(x,y)


plt.xlabel("Most affected states")
plt.xticks(rotation=90)
plt.ylabel("Number of confirmed cases",fontsize=16)
plt.title("India's Most affected states",fontsize=18)
plt.grid(color="k",linestyle="-",linewidth=1)
#plt.legend(loc=1)


plt.show()
