# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
data= pd.read_csv("Prediction.csv")
data
# Out:
#    Month_with_date  Counting_from_april  Confirmed_Cases  Recovered_Cases  \
# 0     April-1-2020                    1             2059              169
# 1     April-2-2020                    2             2545              191
# 2     April-3-2020                    3             3105              230
# 3     April-4-2020                    4             3684              286
# 4     April-5-2020                    5             4293              329
# 5     April-6-2020                    6             4777              394
# 6     April-7-2020                    7             5350              469
# 7     April-8-2020                    8             5915              565
# 8     April-9-2020                    9             6728              635
# 9    April-10-2020                   10             7599              786
# 10   April-11-2020                   11             8453              972
# 11   April-12-2020                   12             9211             1086
# ...

# %%
real_x= data.iloc[:,1].values
real_y= data.iloc[:,2].values
real_x= real_x.reshape(-1,1)
real_y= real_y.reshape(-1,1)

# %%
training_x,testing_x,training_y,testing_y = train_test_split(real_x,real_y,test_size=0.2,random_state=0)

# %%
poly_reg= PolynomialFeatures(degree=2)
real_x_reg= poly_reg.fit_transform(training_x)
poly_reg.fit(real_x_reg,training_y)
Lin2= LinearRegression()
Lin2.fit(real_x_reg,training_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_y=Lin2.predict(poly_reg.fit_transform(testing_x))

# %%
testing_y
# Out:
# array([[90649],
#        [46434],
#        [70768],
#        [29458],
#        [ 9211],
#        [ 3105],
#        [42778],
#        [82047],
#        [95698],
#        [37262],
#        [ 4293],
#        [ 8453]], dtype=int64)

# %%
pred_y
# Out:
# array([[94566.73912935],
#        [48521.32781264],
#        [73360.59661173],
#        [29339.61152673],
#        [ 7286.87590741],
#        [ 6524.94211587],
#        [45434.70186283],
#        [85737.90135619],
#        [99154.34839898],
#        [39607.83072931],
#        [ 5886.03894861],
#        [ 6740.37557575]])

# %%
testing_y[3]
# Out:
# array([29458], dtype=int64)

# %%
pred_y[3]
# Out:
# array([29339.61152673])

# %%
Lin2.predict(poly_reg.fit_transform([[81]]))
# Out:
# array([[323831.91551231]])

# %%
Lin2.predict(poly_reg.fit_transform([[121]]))
# Out:
# array([[759039.64300634]])

# %%
pred_y[11]
# Out:
# array([6740.37557575])

# %%
plt.scatter(training_x,training_y,color="red")
plt.plot(training_x,Lin2.predict(poly_reg.fit_transform(training_x)),color="blue")
plt.title("India's Confirmed Cases")
plt.xlabel("Date from 1 april")
plt.ylabel("Number of confirmed cases")
plt.show()

# %%
plt.scatter(testing_x,testing_y,color="red")
plt.plot(training_x,Lin2.predict(poly_reg.fit_transform(training_x)),color="blue")
plt.title("India's Confirmed Cases")
plt.xlabel("Date from 1 april")
plt.ylabel("Number of confirmed cases")
plt.show()

# %%
r2_score(testing_y,pred_y)*100 #Check Accuracy
# Out:
# 99.34251255043091
